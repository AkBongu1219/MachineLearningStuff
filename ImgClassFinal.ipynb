# %%
import numpy as np
import pywt
import cv2
import matplotlib.pyplot as plt

def w2d(img, mode='haar', level=1):#Wavelength transform function
    imArray = img
    # Datatype conversions
    # Convert to grayscale
    imArray = cv2.cvtColor(imArray, cv2.COLOR_RGB2GRAY)
    # Convert to float
    imArray = np.float32(imArray)
    imArray /= 255
    # Compute coefficients
    coeffs = pywt.wavedec2(imArray, mode, level=level)

    # Process Coefficients
    coeffs_H = list(coeffs)
    coeffs_H[0] *= 0

    # Reconstruction
    imArray_H = pywt.waverec2(coeffs_H, mode)
    imArray_H *= 255
    imArray_H = np.uint8(imArray_H)

    return imArray_H

# Load the image
cropped_img = cv2.imread('C:\\Users\\Guest_User\\Downloads\\dataset\\cropped\\virat_kohli\\virat_kohli1.png')
if cropped_img is None:
    raise ValueError("Error: Could not load image")

# Apply wavelet transform
im_har = w2d(cropped_img, 'db1', 5)

# Display the result
plt.imshow(im_har, cmap='gray')
plt.show()

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 celebrity_file_names_dict = {}
# ----> 2 for img_dir in cropped_image_dirs:
#       3     celebrity_name = img_dir.split('/')[-1]
#       4     file_list = []
#
# NameError: name 'cropped_image_dirs' is not defined
